# %%
import tensorflow as tf
import matplotlib.pyplot as plt

# 1. Define true values and predictions
y_true = tf.constant([1.0, 0.0, 0.0, 1.0])
y_pred = tf.constant([0.9, 0.1, 0.2, 0.8])

# 2. Compute MSE and CCE losses
mse = tf.keras.losses.MeanSquaredError()
cce = tf.keras.losses.CategoricalCrossentropy()

mse_loss = mse(y_true, y_pred)
cce_loss = cce(y_true, y_pred)

print(f"MSE Loss: {mse_loss}")
print(f"CCE Loss: {cce_loss}")

# 3. Modify predictions and recompute losses
y_pred_modified = tf.constant([0.8, 0.2, 0.1, 0.9])
mse_loss_modified = mse(y_true, y_pred_modified)
cce_loss_modified = cce(y_true, y_pred_modified)

print(f"\nModified MSE Loss: {mse_loss_modified}")
print(f"Modified CCE Loss: {cce_loss_modified}")

# 4. Plot loss function values
plt.figure(figsize=(10, 5))
plt.bar(labels, loss_values, color=['red', 'orange', 'red', 'orange'])
plt.title('Comparison of Loss Functions')
plt.ylabel('Loss Value')
plt.show()
# Out:
# MSE Loss: 0.02500000223517418
# CCE Loss: 1.7147984504699707
#
# Modified MSE Loss: 0.02500000037252903
# Modified CCE Loss: 1.7147984504699707
